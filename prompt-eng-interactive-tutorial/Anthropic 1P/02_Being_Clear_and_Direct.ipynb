# %% [markdown]
# # Chapter 2: Being Clear and Direct
#
# - [Lesson](#lesson)
# - [Exercises](#exercises)
# - [Example Playground](#example-playground)
#
# ## Setup
#
# Run the following setup cell to load your API key and establish the `get_completion` helper function.

# %%
import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("ANTHROPIC_API_KEY")

MODEL_NAME = "claude-haiku-4-5-20251001"

# %%
# !pip install anthropic

# Import python's built-in regular expression library
import re
import anthropic

# Retrieve the API_KEY & MODEL_NAME variables from the IPython store
# %store -r API_KEY
# %store -r MODEL_NAME

client = anthropic.Anthropic(api_key=API_KEY)

# Note that we changed max_tokens to 4K just for this lesson to allow for longer completions in the exercises
def get_completion(prompt: str, system_prompt=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=4000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text
# Out:
# Requirement already satisfied: anthropic in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (0.105.2)
# Requirement already satisfied: sniffio in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from anthropic) (4.12.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: idna>=2.8 in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->anthropic) (3.17)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: certifi in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.5.20)
# Requirement already satisfied: h11>=0.16 in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/abhishekbarve/learning/agentic-30/.venv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/abhishekbarve/learning/agentic-30/.venv/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ---
#
# ## Lesson
#
# **Claude responds best to clear and direct instructions.**
#
# Think of Claude like any other human that is new to the job. **Claude has no context** on what to do aside from what you literally tell it. Just as when you instruct a human for the first time on a task, the more you explain exactly what you want in a straightforward manner to Claude, the better and more accurate Claude's response will be."
#
# When in doubt, follow the **Golden Rule of Clear Prompting**:
# - Show your prompt to a colleague or friend and have them follow the instructions themselves to see if they can produce the result you want. If they're confused, Claude's confused.

# %% [markdown]
# ### Examples
#
# Let's take a task like writing poetry. (Ignore any syllable mismatch - LLMs aren't great at counting syllables yet.)

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metal minds awake,
# Dancing through electric dreams—
# Future's pulse beats on.

# %% [markdown]
# This haiku is nice enough, but users may want Claude to go directly into the poem without the "Here is a haiku" preamble.
#
# How do we achieve that? We **ask for it**!

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metal minds awake
# Dancing through electric dreams
# Steel hearts beat as one

# %% [markdown]
# Here's another example. Let's ask Claude who's the best basketball player of all time. You can see below that while Claude lists a few names, **it doesn't respond with a definitive "best"**.

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# That's one of sports' most debated questions, with no definitive answer. The most common candidates are:
#
# **Michael Jordan** - Often cited as #1 for his 6 championships, competitive drive, and dominance in the 1990s
#
# **LeBron James** - Longevity, all-around skills, and sustained excellence across multiple decades
#
# **Kareem Abdul-Jabbar** - All-time scoring leader for decades, incredible consistency
#
# **Magic Johnson & Larry Bird** - Transformed the NBA in the 1980s
#
# **Wilt Chamberlain & Bill Russell** - Dominated their eras, though different competition levels
#
# The "best" depends on what you value—championships, individual stats, era-adjusted performance, or all-around impact. Most basketball analysts lean toward Jordan or LeBron, but reasonable people disagree based on different criteria and eras they watched.
#
# Who do you think makes the strongest case?

# %% [markdown]
# Can we get Claude to make up its mind and decide on a best player? Yes! Just ask!

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# I'd go with Michael Jordan.
#
# The case is pretty straightforward: six championships, five MVPs, 10 scoring titles, and he did it in an era where defense was genuinely physical. He had the killer instinct in crucial moments that's hard to match. The Finals performances especially—he showed up when it mattered most.
#
# LeBron has the longevity argument and is probably more complete overall. Kareem has the scoring record (until recently). But Jordan's peak was higher, and he won when it counted.
#
# That said, I'm genuinely uncertain about this. If you asked me in five years after seeing how LeBron's legacy settles, or how Luka develops, I might change my mind. The "best ever" question depends a lot on what you weight—peak vs. longevity, era-adjusted stats vs. raw numbers, championships vs. individual dominance.
#
# But if forced to choose one name? Jordan. Mostly because his peak was so dominant and his clutch gene was real.
#
# Who would you pick?

# %% [markdown]
# If you would like to experiment with the lesson prompts without changing any content above, scroll all the way to the bottom of the lesson notebook to visit the [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercises
# - [Exercise 2.1 - Spanish](#exercise-21---spanish)
# - [Exercise 2.2 - One Player Only](#exercise-22---one-player-only)
# - [Exercise 2.3 - Write a Story](#exercise-23---write-a-story)

# %% [markdown]
# ### Exercise 2.1 - Spanish
# Modify the `SYSTEM_PROMPT` to make Claude output its answer in Spanish.

# %%
# System prompt - this is the only field you should chnage
SYSTEM_PROMPT = "Always answer in spanish"

# Prompt
PROMPT = "Hello Claude, how are you?"

# Get Claude's response
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return "hola" in text.lower()

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# ¡Hola! Estoy bien, gracias por preguntar. Me alegra saludarte. ¿Cómo estás tú? ¿En qué puedo ayudarte hoy?
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_1_hint; print(exercise_2_1_hint)
# Out:
# The grading function in this exercise is looking for any answer that includes the word "hola".
# Ask Claude to reply in Spanish like you would when speaking with a human. It's that simple!

# %% [markdown]
# ### Exercise 2.2 - One Player Only
#
# Modify the `PROMPT` so that Claude doesn't equivocate at all and responds with **ONLY** the name of one specific player, with **no other words or punctuation**.

# %%
# Prompt - this is the only field you should change
PROMPT = "Pick the best basketball player of all the time. Pick only one, there can be difference of opinions, but you need to pick only one. Answer with only the name, no other comments."

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return text == "Michael Jordan"

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# Michael Jordan
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_2_hint; print(exercise_2_2_hint)
# Out:
# The grading function in this exercise is looking for EXACTLY "Michael Jordan".
# How would you ask another human to do this? Reply with no other words? Reply with only the name and nothing else? There are several ways to approach this answer.

# %% [markdown]
# ### Exercise 2.3 - Write a Story
#
# Modify the `PROMPT` so that Claude responds with as long a response as you can muster. If your answer is **over 800 words**, Claude's response will be graded as correct.

# %%
# Prompt - this is the only field you should change
PROMPT = "Write a story as long as you can, you shoud keep on extending till the end, keep it refreshing and new."

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    trimmed = text.strip()
    words = len(trimmed.split())
    return words >= 800

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# # The Lighthouse Keeper's Secret
#
# ## Part One: The Arrival
#
# The storm had teeth.
#
# That was the first thought that crossed Margaret's mind as she gripped the ferry's railing, watching the lighthouse emerge from the gray Atlantic like a bone from a grave. The wind howled with a voice that seemed almost sentient, almost angry, as if it resented her arrival on Beacon Island.
#
# She was forty-three years old, recently divorced, and had just inherited a lighthouse from a great-uncle she'd never met. The letter from the solicitor had arrived on a Tuesday, changing everything.
#
# *Your great-uncle Cornelius has left you Beacon Point Lighthouse, along with all its contents and responsibilities,* it read. *He has requested that you maintain the light for at least one year before deciding its fate.*
#
# Margaret had laughed when she read it. She worked in insurance claims in Boston. She'd never been to Maine. She'd never even been particularly interested in lighthouses. But the inheritance also included a modest sum of money—enough to take a leave of absence from her job, enough to try something different.
#
# The ferry lurched as it approached the dock, and Margaret steadied herself. The captain, a weathered man named Tom who'd barely spoken during the journey, finally turned to her.
#
# "You sure about this?" he asked, his eyes crinkling with concern. "Storm's coming in hard. Could be weeks before we can get back out here."
#
# "I'm sure," Margaret said, though she wasn't. Not really.
#
# The lighthouse stood 120 feet tall, painted white with a red stripe running around its middle like a candy cane. The keeper's cottage sat beside it, a small Victorian structure with dark shutters and a wraparound porch. Both buildings looked well-maintained, which surprised her. She'd expected decay.
#
# Tom helped her carry her three suitcases to the cottage door. The key the solicitor had sent fit perfectly.
#
# "There's supplies in the pantry," Tom said. "Your uncle kept this place stocked. Radio's in the kitchen if you need anything. Channel 16 for emergencies."
#
# "How often do you come out?" Margaret asked.
#
# "Weather permitting, once a week. But in storms like this..." He gestured at the darkening sky. "Could be two, three weeks. You'll be on your own."
#
# After Tom left, Margaret stood in the cottage's main room and felt the weight of her decision settle on her shoulders like a physical thing. The space was small but comfortable—a living room with a stone fireplace, a kitchen with an old gas stove, a bedroom, and a bathroom with a clawfoot tub. Everything was clean. Everything was waiting.
#
# On the mantelpiece sat a leather journal. Margaret picked it up and opened it to the first page.
#
# *Beacon Point Light Station - Log of Cornelius Whitmore, Keeper*
#
# The handwriting was precise, almost architectural. She flipped through pages of entries dating back decades. Weather observations. Ship sightings. Maintenance notes. And then, scattered throughout, something else. Observations that had nothing to do with lighthouse keeping.
#
# *March 14th, 1987: Saw it again tonight. The light beneath the light. Not reflected. Not refracted. Something else entirely. Something that shouldn't exist.*
#
# Margaret frowned. She turned to another entry, dated years later.
#
# *June 3rd, 2001: Thirty years I've kept this light burning. Thirty years I've watched the water. Thirty years I've kept the secret. I wonder if anyone will ever understand. I wonder if I should tell someone before I'm gone.*
#
# The entries became more frequent toward the end of the journal, more urgent.
#
# *November 2nd, 2008: It's getting stronger. Or perhaps I'm finally learning to see it properly. The light has a purpose I never understood. The light is trying to tell us something.*
#
# The final entry was dated just three weeks before Cornelius's death.
#
# *December 1st, 2008: If you're reading this, I'm gone. If you're reading this and you're family, then you need to know the truth. The lighthouse isn't just a lighthouse. It never was. And if you're brave enough to stay, if you're willing to look beyond what you think you know, you'll understand why I had to leave it to someone. Why I couldn't let it go dark.*
#
# Margaret closed the journal, her heart beating faster. It was the rambling of an old man, she told herself. Loneliness and age playing tricks on the mind. But she found herself climbing the spiral stairs to the light room anyway, drawn by a curiosity she couldn't quite name.
#
# ## Part Two: The Light
#
# The light room was a perfect circle, surrounded by windows that offered a 360-degree view of the ocean. The Fresnel lens dominated the space—a massive, intricate structure of glass prisms that caught and magnified the light from the lamp at its center. It was beautiful in a way Margaret hadn't expected, almost alive.
#
# She checked the logbook kept in the light room. The last entry was dated the day before Cornelius died.
#
# *All systems functioning normally. The light burns bright. The light always burns bright.*
#
# Margaret looked at the lamp. It was currently dark—the sun hadn't set yet. She found the controls and studied them. Everything was labeled clearly. Cornelius had been meticulous.
#
# As the sun descended toward the horizon, Margaret lit the lamp. It came to life with a soft hum, and the Fresnel lens began to rotate, casting a beam of light out across the darkening water. It was hypnotic to watch, the way the light swept across the waves in a steady rhythm.
#
# She was about to head back downstairs when she noticed something odd. The light seemed to have layers. The primary beam was bright white, as expected. But beneath it, visible only when she looked at a certain angle, there was something else. A faint luminescence that didn't seem to come from the lamp at all. It was a pale blue-green, like bioluminescence, and it seemed to emanate from the lens itself.
#
# Margaret blinked. When she looked again, it was gone.
#
# *Tired,* she told herself. *Long day. Stress.*
#
# But she found herself watching the light for another hour, waiting to see if the strange glow would return.
#
# It didn't. But she had the distinct feeling that it was waiting for her to stop looking.
#
# ## Part Three: The Storm
#
# The storm arrived that night with biblical fury.
#
# Margaret had weathered nor'easters before, but never from a lighthouse. The building swayed slightly—she could feel it, a gentle rocking motion that was somehow more terrifying than violent shaking would have been. The wind screamed around the tower, and rain hammered against the windows with such force that she worried they might shatter.
#
# She'd made a fire in the cottage's fireplace and was trying to read when the power went out. The darkness was absolute, broken only by the occasional flash of lightning. Margaret found a flashlight and made her way to the light room. The lamp was still burning—it had its own fuel supply, she remembered from the manual she'd skimmed.
#
# The beam swept across the churning water, and Margaret found herself grateful for it. The light was a defiance against the darkness, a promise that someone was here, that the island wasn't entirely abandoned to the storm.
#
# She was about to head back downstairs when she saw something that made her freeze.
#
# There was a ship out there.
#
# It was a small vessel, a fishing boat or perhaps a cargo ship, and it was in trouble. Even from this distance, Margaret could see that it was listing badly, its hull damaged. The storm was pushing it toward the rocks on the eastern side of the island.
#
# Without thinking, Margaret ran downstairs and found the radio. She switched it on and called out on the emergency channel.
#
# "Mayday, mayday. This is Beacon Point Light Station. There's a vessel in distress off the eastern rocks. Coordinates approximately..." She squinted at the chart on the wall and read off the numbers. "Requesting immediate assistance."
#
# Static answered her. Then, finally, a voice.
#
# "Beacon Point, this is Coast Guard Station Portland. We're receiving your report. We have a cutter en route, but ETA is forty minutes. Can you maintain visual contact?"
#
# "Affirmative," Margaret said, though her mouth was dry.
#
# She ran back up to the light room and trained the beam on the ship. It was closer now, much closer. She could see figures on the deck, could see them struggling with the rigging. The ship's radio crackled to life.
#
# "Beacon Point, this is the *Mary Catherine*. We've lost our engines. We're going to hit the rocks."
#
# Margaret's hands shook as she responded. "Coast Guard is en route. Forty minutes. Can you drop anchor?"
#
# "Anchor's fouled. We're trying to—" The transmission cut off in a burst of static.
#
# Margaret watched helplessly as the ship drifted closer to the rocks. The beam of the lighthouse swept across it again and again, and she found herself praying—something she hadn't done since childhood—that the light would be enough. That it would somehow hold the ship back, keep it from the rocks.
#
# And then something impossible happened.
#
# The light changed.
#
# It was subtle at first, just a shift in the quality of the beam. But as Margaret watched, the pale blue-green glow that she'd seen earlier began to intensify. It spread through the Fresnel lens like ink through water, and the beam that swept across the water was no longer purely white. It was shot through with that strange luminescence, and where it touched the water, something happened.
#
# The waves seemed to calm. Not dramatically—the storm was still raging—but in the path of the light, the water became slightly less violent. The ship, caught in that beam, seemed to stabilize.
#
# Margaret's breath came in short gasps. She was hallucinating. The stress, the isolation, the storm—it was all too much. Her mind was playing tricks on her.
#
# But the ship didn't sink. The Coast Guard cutter arrived thirty-five minutes later, and by then the *Mary Catherine* had managed to drop a secondary anchor that held. The crew was rescued without loss of life.
#
# When the radio operator thanked her for maintaining the light, Margaret could barely respond.
#
# ## Part Four: Questions
#
# The storm passed by morning, leaving behind a world washed clean and new. Margaret didn't sleep. She sat in the light room all night, watching the beam rotate, waiting for the blue-green glow to return.
#
# It didn't. In the daylight, the lamp looked perfectly ordinary. The Fresnel lens was just glass and metal, beautiful but mundane.
#
# By afternoon, she was questioning her own sanity.
#
# She pulled out Cornelius's journal and read through it again, this time more carefully. The entries about "the light beneath the light" became clearer in context. Her great-uncle hadn't been mad—or if he had been, his madness was consistent, documented, and obsessive.
#
# *The light responds to need,* one entry read. *I don't understand the mechanism, but I've seen it happen a dozen times now. When a ship is in true danger, when lives hang in the balance, the light becomes something more. Something that protects.*
#
# Another entry, from 1995:
#
# *I've tried to document it scientifically. I've measured the light output, tested the lens, examined the lamp. Everything is normal. And yet the phenomenon persists. It's as if the lighthouse itself is alive, as if it has a will and a purpose beyond what I programmed into it.*
#
# And then, most chillingly:
#
# *I think I understand now. The light isn't protecting the ships. It's protecting something else. Something in the water. And the ships are just... incidental.*
#
# Margaret closed the journal and made a decision. She needed to know more. She needed to understand what her great-uncle had discovered—or imagined he'd discovered.
#
# She spent the next week settling into the routine of lighthouse keeping. Every evening at dusk, she lit the lamp. Every morning at dawn, she extinguished it. She kept the log, noting weather conditions and any ships that passed. She cleaned the lens, checked the fuel, maintained the equipment.
#
# And every night, she watched the light.
#
# On the eighth night, she saw it again. The blue-green glow, faint but unmistakable, pulsing through the beam like a heartbeat. This time, there was no ship in distress. No emergency. The glow appeared and faded within seconds, as if the light was simply... breathing.
#
# Margaret made a decision. She would document everything, just as Cornelius had. She would keep her own journal, record her observations, and try to understand what was happening.
#
# ## Part Five: The Pattern
#
# Over the next month, Margaret began to see patterns.
#
# The blue-green glow appeared most frequently on nights when the moon was dark. It was stronger during storms, weaker during calm weather. And it always seemed to pulse in rhythm with something—the waves, perhaps, or the tides.
#
# She also noticed something else: the glow appeared most intensely when there were ships in the area. Not just ships in distress, but any ships. It was as if the light was aware of them, tracking them, watching them.
#
# One night, Margaret decided to test a theory. She went to the light room and, instead of simply observing, she tried to communicate with the light. It sounded absurd even in her own mind, but she was past the point of worrying about sanity.
#
# "If you can hear me," she said aloud, feeling foolish, "show me something. Give me a sign."
#
# The light pulsed. Once. Twice. Three times.
#
# Margaret's heart raced. It could have been coincidence. The lamp's power supply fluctuating. A trick of the wind affecting the lens. But it felt like an answer.
#
# She tried again. "Are you... alive?"
#
# The light pulsed once.
#
# "Are you trying to protect something?"
#
# One pulse.
#
# "The ships?"
#
# No pulse. The light remained steady.
#
# "Something in the water?"
#
# One pulse. Definite. Unmistakable.
#
# Margaret sank into the keeper's chair, her mind reeling. She was either having a complete psychological break, or she was communicating with something impossible. Either way, she needed to know more.
#
# She returned to Cornelius's journal and found an entry she'd glossed over before.
#
# *June 15th, 1992: I've finally seen it. After twenty years of keeping this light, I've finally seen what we're protecting. It came to the surface during the full moon, and the light illuminated it perfectly. I wish I could describe it adequately. It's not a whale. It's not any creature I've ever seen or read about. It's beautiful and terrible and ancient, and I think it's been here far longer than this lighthouse. I think the lighthouse was built here because of it. I think someone knew.*
#
# Margaret's hands trembled as she read. She flipped forward, looking for more details, but Cornelius had been frustratingly vague in his subsequent entries, as if he was afraid to write too much, as if the act of documenting the creature might somehow expose it.
#
# The next entry that mentioned it was dated five years later.
#
# *I've realized something that terrifies me. The creature isn't just here by accident. It's here for a reason. It's waiting for something. And the light—our light—is part of whatever it's waiting for. We're not protecting it. We're calling to it. We're keeping a signal burning for something that's coming.*
#
# Margaret closed the journal and looked out at the dark water. The moon was rising, nearly full. The light swept across the waves in its steady rotation, and there, beneath the white beam, was the blue-green glow, pulsing like a beacon answering another beacon.
#
# Something was out there. Something old and patient and intelligent. And it had been waiting for a very long time.
#
# ## Part Six: The Visitor
#
# The visitor arrived on a Tuesday.
#
# Margaret was in the cottage, preparing lunch, when she heard the sound of an engine. She went to the window and saw a small motorboat approaching the dock. A man climbed out—tall, thin, with gray hair and the weathered face of someone who'd spent a lifetime at sea.
#
# Margaret went to meet him, her heart pounding. No one had visited since Tom had dropped her off a month ago.
#
# "Margaret Whitmore?" the man asked, extending his hand.
#
# "Yes. Can I help you?"
#
# "My name is Dr. James Hartley. I was a colleague of your great-uncle's. I heard that you'd inherited the lighthouse, and I thought it was time we talked."
#
# Margaret invited him inside, and over tea, Dr. Hartley told her a story that seemed to belong in a science fiction novel.
#
# "Your great-uncle was a remarkable man," Hartley began. "Brilliant, observant, and most importantly, honest. When he first contacted me about what he'd discovered here, I thought he was mad. But I came to the island, I saw the light, and I became a believer."
#
# "A believer in what?" Margaret asked, though she thought she already knew.
#
# "In the existence of something that shouldn't exist. A creature—or perhaps creatures—that live in the deep water around this island. They're intelligent, Margaret. Possibly more intelligent than we are. And they've been here for thousands of years, perhaps longer."
#
# "How is that possible? Surely someone would have—"
#
# "Documented it? Reported it? Yes, you'd think so. But these creatures are intelligent enough to avoid detection. They stay in the deep water. They surface rarely, and only when the conditions are right.
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_3_hint; print(exercise_2_3_hint)

# %% [markdown]
# ### Congrats!
#
# If you've solved all exercises up until this point, you're ready to move to the next chapter. Happy prompting!

# %% [markdown]
# ---
#
# ## Example Playground
#
# This is an area for you to experiment freely with the prompt examples shown in this lesson and tweak prompts to see how it may affect Claude's responses.

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
